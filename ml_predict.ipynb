# %% [markdown]
# # Prediction with Saved Tensorflow Classifier

# %%
import neo4j_bq as bq
import pandas as pd
import numpy as np
import neo4j_arrow as na
from google.cloud import bigquery
from tensorflow import keras
import tensorflow as tf
from graphdatascience import GraphDataScience

# %% [markdown]
# ## Create BigQuery Table to Hold Paper Subject Predictions

# %%
def bq_tbl_exists(client, table_ref):
    from google.cloud.exceptions import NotFound
    try:
        client.get_table(table_ref)
        return True
    except NotFound:
        return False

# %%
client = bigquery.Client()
table_id = "neo4jgraphconnectdemo2022.ogb_mag240m.paper_predictions3"

# %%
schema = [
    bigquery.SchemaField("paper", "INTEGER", mode="REQUIRED"),
    bigquery.SchemaField("years", "INTEGER", mode="REQUIRED"),
    bigquery.SchemaField("flag", "INTEGER", mode="REQUIRED"),
    bigquery.SchemaField("predictedFlag", "INTEGER", mode="REQUIRED")
]

if not bq_tbl_exists(client, table_id):
    table = bigquery.Table(table_id, schema=schema)
    table = client.create_table(table)
    print(f"Created table {table.project}.{table.dataset_id}.{table.table_id}")
else:
    table = client.get_table(table_id)
    print(f"Found table {table.project}.{table.dataset_id}.{table.table_id}")
# Out:
# Created table neo4jgraphconnectdemo2022.ogb_mag240m.paper_predictions3

# %% [markdown]
# ## Predict Paper Subjects (a.k.a. "Flags")

# %%
with open('pass.txt', mode='r') as f:
    password = f.readline().strip()

# %%
model = keras.models.load_model('simple-paper-classifier-5')
probability_model = tf.keras.Sequential([model, tf.keras.layers.Softmax()])
# Out:
# 2022-06-11 15:57:17.549160: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.

# %%
# Replace with the actual URI, username and password
CONNECTION_URI = "neo4j+s://demo2.graphconnect.app:7687"
USERNAME = "neo4j"

# Client instantiation
gds = GraphDataScience(
    CONNECTION_URI,
    auth=(USERNAME, password)
)

# %%
G=gds.graph.get("gcdemo")

# %%
def predict_for_year(year):
    
    #sub-project and read papers
    g, _ = gds.beta.graph.project.subgraph('proj', G,  f'n:Paper AND (n.years = {year})', '*', concurrency=224)
    arrow_client = na.Neo4jArrowClient('demo2.graphconnect.app', graph="proj", password=password, concurrency=224)
    dfs=[]
    for chunk in arrow_client.read_nodes(["graphEmbedding", "flag", "years"]):
        dfs.append(chunk.to_pandas())
    df = pd.concat(dfs)
    
    #drop subgraph projection
    g.drop()

    #predeict paper subjects
    X = np.stack(df.graphEmbedding, axis=0)
    df["predictedFlag"] = np.argmax(model.predict(X, batch_size=100_000), axis = 1)
    
    #write to BigQuery
    bq_client =  bigquery.Client()
    job = bq_client.load_table_from_dataframe(df[["nodeId","flag", "years","predictedFlag"]].rename(columns={"nodeId":"paper"}), table_id)
    print(job.result())  # Wait for the job to complete.
    
    return df.shape[0]

# %%
papers = 0
for i in range (1901,2022):
    papers += predict_for_year(i)
    print(f'Finished year {i}. Predicted {papers} papers so far')
    print('-------------------------------')
# Out:
# LoadJob<project=neo4jgraphconnectdemo2022, location=US, id=631f559f-a36b-4c06-8cbd-0e1f4339b7f5>
# Finished year 1901. Predicted 22578 papers so far
# -------------------------------
# LoadJob<project=neo4jgraphconnectdemo2022, location=US, id=07c8213f-2e9e-45a1-9e74-33a5bf0defe4>
# Finished year 1902. Predicted 45854 papers so far
# -------------------------------
# LoadJob<project=neo4jgraphconnectdemo2022, location=US, id=b221560d-23de-48f3-833f-7de56697a5f0>
# Finished year 1903. Predicted 70255 papers so far
# -------------------------------
# LoadJob<project=neo4jgraphconnectdemo2022, location=US, id=48c5df12-b3a7-406a-9cb9-57cd9e86d224>
# Finished year 1904. Predicted 94543 papers so far
# -------------------------------
# LoadJob<project=neo4jgraphconnectdemo2022, location=US, id=b9db5262-b360-478c-8a5b-265d0f717d57>
# Finished year 1905. Predicted 120390 papers so far
# -------------------------------
# LoadJob<project=neo4jgraphconnectdemo2022, location=US, id=37a4bef5-c731-40cb-a858-7e443cfe4c6b>
# Finished year 1906. Predicted 147255 papers so far
# -------------------------------
# LoadJob<project=neo4jgraphconnectdemo2022, location=US, id=bd2f5505-ced8-4e31-a562-c57264003654>
# Finished year 1907. Predicted 175021 papers so far
# -------------------------------
# LoadJob<project=neo4jgraphconnectdemo2022, location=US, id=93c07593-5577-49d8-8ed4-2d768f1dbe13>
# Finished year 1908. Predicted 204605 papers so far
# -------------------------------
# LoadJob<project=neo4jgraphconnectdemo2022, location=US, id=8636bf41-0309-4268-820e-499f5e6e9176>
# Finished year 1909. Predicted 235335 papers so far
# -------------------------------
# LoadJob<project=neo4jgraphconnectdemo2022, location=US, id=b375ba8d-e5ba-4358-b8ab-e7a368b2e2dc>
# Finished year 1910. Predicted 268430 papers so far
# -------------------------------
# LoadJob<project=neo4jgraphconnectdemo2022, location=US, id=d465b0a6-b401-4481-a67f-6d13ae12b439>
# Finished year 1911. Predicted 301930 papers so far
# -------------------------------
# LoadJob<project=neo4jgraphconnectdemo2022, location=US, id=6f7572ce-1b60-460d-a0f0-00a020db0c3b>
# Finished year 1912. Predicted 336010 papers so far
# -------------------------------
# LoadJob<project=neo4jgraphconnectdemo2022, location=US, id=cc839170-36f2-4a52-adc6-8e6e93053f5c>
# Finished year 1913. Predicted 372034 papers so far
# -------------------------------
# LoadJob<project=neo4jgraphconnectdemo2022, location=US, id=88056988-40ec-4920-b14b-183560ba5234>
# Finished year 1914. Predicted 406352 papers so far
# -------------------------------
# LoadJob<project=neo4jgraphconnectdemo2022, location=US, id=6ef979fc-059d-449b-b81b-8cb7aebbcd88>
# Finished year 1915. Predicted 437883 papers so far
# -------------------------------
# LoadJob<project=neo4jgraphconnectdemo2022, location=US, id=18155848-6d5e-48db-86a3-b0132dee1911>
# Finished year 1916. Predicted 469020 papers so far
# -------------------------------
# LoadJob<project=neo4jgraphconnectdemo2022, location=US, id=ca2b0620-2262-4860-9880-85547e80938c>
# Finished year 1917. Predicted 498651 papers so far
# -------------------------------
# LoadJob<project=neo4jgraphconnectdemo2022, location=US, id=b9631370-e841-497f-94de-c6b63a037238>
# Finished year 1918. Predicted 527846 papers so far
# -------------------------------
# LoadJob<project=neo4jgraphconnectdemo2022, location=US, id=b945fed4-e4ff-4242-bb91-1c6ec8340582>
# Finished year 1919. Predicted 557988 papers so far
# -------------------------------
# LoadJob<project=neo4jgraphconnectdemo2022, location=US, id=7811cdde-8732-4dd3-91b1-c3e4aaa8026c>
# Finished year 1920. Predicted 593433 papers so far
# -------------------------------
# LoadJob<project=neo4jgraphconnectdemo2022, location=US, id=324382e4-0d22-43ae-a0c9-7dc07c1270c0>
# Finished year 1921. Predicted 630460 papers so far
# -------------------------------
# LoadJob<project=neo4jgraphconnectdemo2022, location=US, id=167674db-babf-4d1b-878a-04e23aea1c04>
# Finished year 1922. Predicted 672602 papers so far
# -------------------------------
# LoadJob<project=neo4jgraphconnectdemo2022, location=US, id=69b9f859-3188-4d0d-81b0-40515a38fbfc>
# Finished year 1923. Predicted 718159 papers so far
# -------------------------------
# LoadJob<project=neo4jgraphconnectdemo2022, location=US, id=c850b47d-465f-4b16-9d08-df069431ecb8>
# Finished year 1924. Predicted 767479 papers so far
# -------------------------------
# LoadJob<project=neo4jgraphconnectdemo2022, location=US, id=7f4bd60f-0570-4f8e-9b1f-e884258eec26>
# Finished year 1925. Predicted 819091 papers so far
# -------------------------------
# LoadJob<project=neo4jgraphconnectdemo2022, location=US, id=40c7959a-e5f7-4bdd-86fc-8c4cb84a1295>
# Finished year 1926. Predicted 875095 papers so far
# -------------------------------
# LoadJob<project=neo4jgraphconnectdemo2022, location=US, id=1e9f32dc-5bdc-4de8-b531-a9bd93abfba7>
# Finished year 1927. Predicted 933388 papers so far
# -------------------------------
# LoadJob<project=neo4jgraphconnectdemo2022, location=US, id=06210d04-6d3b-48fd-8543-73d7f1739b57>
# Finished year 1928. Predicted 994536 papers so far
# -------------------------------
# LoadJob<project=neo4jgraphconnectdemo2022, location=US, id=02f09931-fa54-4c0b-b8a4-16123e720f99>
# Finished year 1929. Predicted 1057889 papers so far
# -------------------------------
# LoadJob<project=neo4jgraphconnectdemo2022, location=US, id=8d7c3b6b-2ad8-41c9-90b2-495621593fea>
# Finished year 1930. Predicted 1127528 papers so far
# -------------------------------
# LoadJob<project=neo4jgraphconnectdemo2022, location=US, id=9fdd6e4c-9a22-4c34-bd0c-ce070ea84129>
# Finished year 1931. Predicted 1196275 papers so far
# -------------------------------
# LoadJob<project=neo4jgraphconnectdemo2022, location=US, id=75e624df-a79c-44d6-b7fa-8536fb72de99>
# Finished year 1932. Predicted 1266402 papers so far
# -------------------------------
# LoadJob<project=neo4jgraphconnectdemo2022, location=US, id=01193f6e-83b8-49cc-80ca-2a80443ae49e>
# Finished year 1933. Predicted 1338113 papers so far
# -------------------------------
# LoadJob<project=neo4jgraphconnectdemo2022, location=US, id=67af9778-d110-4ea7-914c-52d4d6bf04ba>
# Finished year 1934. Predicted 1409426 papers so far
# -------------------------------
# LoadJob<project=neo4jgraphconnectdemo2022, location=US, id=a71bd4af-1cda-471e-ad95-e78c831415de>
# Finished year 1935. Predicted 1484390 papers so far
# -------------------------------
# LoadJob<project=neo4jgraphconnectdemo2022, location=US, id=0466c244-2d02-4a0e-82f2-b67dcedf5f8a>
# Finished year 1936. Predicted 1561654 papers so far
# -------------------------------
# LoadJob<project=neo4jgraphconnectdemo2022, location=US, id=77e9ff4f-3c55-4dd2-a3a9-53583b99b09b>
# Finished year 1937. Predicted 1639182 papers so far
# -------------------------------
# LoadJob<project=neo4jgraphconnectdemo2022, location=US, id=64f15697-c220-470d-bd6a-2d624be5befb>
# Finished year 1938. Predicted 1719121 papers so far
# -------------------------------
# LoadJob<project=neo4jgraphconnectdemo2022, location=US, id=d4a32592-1ca2-460f-9202-db1d098bc70a>
# Finished year 1939. Predicted 1798995 papers so far
# -------------------------------
# LoadJob<project=neo4jgraphconnectdemo2022, location=US, id=f7e8c8e4-f494-4fd1-952d-00c42d478549>
# Finished year 1940. Predicted 1901023 papers so far
# -------------------------------
# LoadJob<project=neo4jgraphconnectdemo2022, location=US, id=ba13a10c-1666-4f18-997b-e6f9639d50c9>
# Finished year 1941. Predicted 1972469 papers so far
# -------------------------------
# LoadJob<project=neo4jgraphconnectdemo2022, location=US, id=62a932f2-2f9f-4ee3-b619-23a27f50d2b7>
# Finished year 1942. Predicted 2041425 papers so far
# -------------------------------
# LoadJob<project=neo4jgraphconnectdemo2022, location=US, id=e51f08ea-67dd-41c5-a5e1-bcf0947a22ba>
# Finished year 1943. Predicted 2105855 papers so far
# -------------------------------
# LoadJob<project=neo4jgraphconnectdemo2022, location=US, id=bd19cde7-b3a8-47bb-a729-0a82c6efd91a>
# Finished year 1944. Predicted 2165685 papers so far
# -------------------------------
# LoadJob<project=neo4jgraphconnectdemo2022, location=US, id=986cb339-c7e7-4f85-b192-ca474089b2ea>
# Finished year 1945. Predicted 2231692 papers so far
# -------------------------------
# LoadJob<project=neo4jgraphconnectdemo2022, location=US, id=72c05ad5-0fdd-4eb3-ac76-31d015a75f03>
# Finished year 1946. Predicted 2320703 papers so far
# -------------------------------
# LoadJob<project=neo4jgraphconnectdemo2022, location=US, id=6710ea85-2ea5-4676-8b1e-0fc4fa3bb4ab>
# Finished year 1947. Predicted 2429302 papers so far
# -------------------------------
# LoadJob<project=neo4jgraphconnectdemo2022, location=US, id=063e4282-7fec-48c9-85b2-2fec10b95217>
# Finished year 1948. Predicted 2551942 papers so far
# -------------------------------
# LoadJob<project=neo4jgraphconnectdemo2022, location=US, id=827e519a-c1a3-4add-9b12-ef0b40587e8b>
# Finished year 1949. Predicted 2684126 papers so far
# -------------------------------
# LoadJob<project=neo4jgraphconnectdemo2022, location=US, id=a08ce907-1dc4-47db-baf0-de5b9d48f5a9>
# Finished year 1950. Predicted 2863129 papers so far
# -------------------------------
# LoadJob<project=neo4jgraphconnectdemo2022, location=US, id=2d61215c-90e7-438b-b362-e390d51384f3>
# Finished year 1951. Predicted 3045747 papers so far
# -------------------------------
# LoadJob<project=neo4jgraphconnectdemo2022, location=US, id=2183dcff-011c-47ec-94ff-ffd0a280c490>
# Finished year 1952. Predicted 3236092 papers so far
# -------------------------------
# LoadJob<project=neo4jgraphconnectdemo2022, location=US, id=888915f7-92c5-4f61-83ed-12498df22de1>
# Finished year 1953. Predicted 3434596 papers so far
# -------------------------------
# LoadJob<project=neo4jgraphconnectdemo2022, location=US, id=d0af6c05-fa35-4927-a27d-7d8aa29e433e>
# Finished year 1954. Predicted 3642228 papers so far
# -------------------------------
# LoadJob<project=neo4jgraphconnectdemo2022, location=US, id=1397f5a5-789e-4e7a-bcdc-08368381fc5f>
# Finished year 1955. Predicted 3857546 papers so far
# -------------------------------
# LoadJob<project=neo4jgraphconnectdemo2022, location=US, id=21eb5122-77e0-4a77-945a-221f048116bd>
# Finished year 1956. Predicted 4079058 papers so far
# -------------------------------
# LoadJob<project=neo4jgraphconnectdemo2022, location=US, id=cdcf2bd7-a700-4928-915f-5463a1ee582d>
# Finished year 1957. Predicted 4311568 papers so far
# -------------------------------
# LoadJob<project=neo4jgraphconnectdemo2022, location=US, id=5614ea97-9162-438e-a49d-0c3af105c757>
# Finished year 1958. Predicted 4554053 papers so far
# -------------------------------
# LoadJob<project=neo4jgraphconnectdemo2022, location=US, id=a6af5da1-e777-43c1-840d-67068bb48869>
# Finished year 1959. Predicted 4812172 papers so far
# -------------------------------
# LoadJob<project=neo4jgraphconnectdemo2022, location=US, id=5d1e8113-9223-439f-b0ba-59cc792a0074>
# Finished year 1960. Predicted 5115878 papers so far
# -------------------------------
# LoadJob<project=neo4jgraphconnectdemo2022, location=US, id=e6b37633-f212-4318-8f18-e91cd8000474>
# Finished year 1961. Predicted 5408608 papers so far
# -------------------------------
# LoadJob<project=neo4jgraphconnectdemo2022, location=US, id=2228262b-2890-4b1c-a630-379cf28ae2a8>
# Finished year 1962. Predicted 5717402 papers so far
# -------------------------------
# LoadJob<project=neo4jgraphconnectdemo2022, location=US, id=07de7291-bb1f-43d7-ae93-ee4f697b2fe8>
# Finished year 1963. Predicted 6057273 papers so far
# -------------------------------
# LoadJob<project=neo4jgraphconnectdemo2022, location=US, id=9ac15eb5-a6a6-4a31-9962-2963e5df8998>
# Finished year 1964. Predicted 6426758 papers so far
# -------------------------------
# LoadJob<project=neo4jgraphconnectdemo2022, location=US, id=8b688342-c69b-4bfd-ab54-9e533501998b>
# Finished year 1965. Predicted 6829108 papers so far
# -------------------------------
# LoadJob<project=neo4jgraphconnectdemo2022, location=US, id=d4e6f68f-07e5-4a7b-8832-125e11f07938>
# Finished year 1966. Predicted 7248012 papers so far
# -------------------------------
# LoadJob<project=neo4jgraphconnectdemo2022, location=US, id=7cb51486-4454-46f8-9bab-c13a439d16da>
# Finished year 1967. Predicted 7702256 papers so far
# -------------------------------
# LoadJob<project=neo4jgraphconnectdemo2022, location=US, id=3f903772-80e0-4a4d-b899-bbe1524cf3e8>
# Finished year 1968. Predicted 8186313 papers so far
# -------------------------------
# LoadJob<project=neo4jgraphconnectdemo2022, location=US, id=a6a4646e-14f6-4b33-842b-4f9049e1d786>
# Finished year 1969. Predicted 8705559 papers so far
# -------------------------------
# LoadJob<project=neo4jgraphconnectdemo2022, location=US, id=dcb7cdb0-9fe2-4582-bb2e-0cbeb3aec529>
# Finished year 1970. Predicted 9322481 papers so far
# -------------------------------
# LoadJob<project=neo4jgraphconnectdemo2022, location=US, id=b96f2980-1532-4f9c-8c18-921ac5c5d70a>
# Finished year 1971. Predicted 9891535 papers so far
# -------------------------------
# LoadJob<project=neo4jgraphconnectdemo2022, location=US, id=fd878217-8407-484c-bfa4-6afce103d157>
# Finished year 1972. Predicted 10484208 papers so far
# -------------------------------
# LoadJob<project=neo4jgraphconnectdemo2022, location=US, id=44bcd7c6-bbd7-4fc2-a71d-6401245d539f>
# Finished year 1973. Predicted 11094764 papers so far
# -------------------------------
# LoadJob<project=neo4jgraphconnectdemo2022, location=US, id=097e9188-3a91-490c-9d88-0e09b7429e3d>
# Finished year 1974. Predicted 11726423 papers so far
# -------------------------------
# LoadJob<project=neo4jgraphconnectdemo2022, location=US, id=418212ba-091e-45b7-927b-34393298c925>
# Finished year 1975. Predicted 12380825 papers so far
# -------------------------------
# LoadJob<project=neo4jgraphconnectdemo2022, location=US, id=0043fccd-f9a3-4bb8-b426-64587783b7a7>
# Finished year 1976. Predicted 13049063 papers so far
# -------------------------------
# LoadJob<project=neo4jgraphconnectdemo2022, location=US, id=786e4abb-f28c-4511-8e4d-9d42277dfa20>
# Finished year 1977. Predicted 13740741 papers so far
# -------------------------------
# LoadJob<project=neo4jgraphconnectdemo2022, location=US, id=99fc135c-5105-486f-9227-c331ad000652>
# Finished year 1978. Predicted 14460358 papers so far
# -------------------------------
# LoadJob<project=neo4jgraphconnectdemo2022, location=US, id=8670e6a4-a6a0-4c5c-a864-fc21b50239ee>
# Finished year 1979. Predicted 15203494 papers so far
# -------------------------------
# LoadJob<project=neo4jgraphconnectdemo2022, location=US, id=f51ee4a2-1b08-45c7-b0df-10470937f676>
# Finished year 1980. Predicted 16037655 papers so far
# -------------------------------
# LoadJob<project=neo4jgraphconnectdemo2022, location=US, id=4c015b78-e5da-423d-9716-b9cf46e57a9a>
# Finished year 1981. Predicted 16842064 papers so far
# -------------------------------
# LoadJob<project=neo4jgraphconnectdemo2022, location=US, id=df435013-2e54-447c-8587-f2ed40174552>
# Finished year 1982. Predicted 17668028 papers so far
# -------------------------------
# LoadJob<project=neo4jgraphconnectdemo2022, location=US, id=e0784724-c528-4893-8bdd-282d04778705>
# Finished year 1983. Predicted 18533939 papers so far
# -------------------------------
# LoadJob<project=neo4jgraphconnectdemo2022, location=US, id=9a2b2431-7e30-4ab7-b667-5be1a092232c>
# Finished year 1984. Predicted 19449712 papers so far
# -------------------------------
# LoadJob<project=neo4jgraphconnectdemo2022, location=US, id=3c018e1c-4fe6-4ecc-bd73-36fd2b232ba6>
# Finished year 1985. Predicted 20404243 papers so far
# -------------------------------
# LoadJob<project=neo4jgraphconnectdemo2022, location=US, id=8ee6cdcd-026c-4972-814d-9874c4430cf7>
# Finished year 1986. Predicted 21400530 papers so far
# -------------------------------
# LoadJob<project=neo4jgraphconnectdemo2022, location=US, id=d30329d0-3be4-439a-8f93-1dbd0ec335c1>
# Finished year 1987. Predicted 22455371 papers so far
# -------------------------------
# LoadJob<project=neo4jgraphconnectdemo2022, location=US, id=df2bb1f3-c1dd-47ac-bee0-6c3cd7026de7>
# Finished year 1988. Predicted 23563972 papers so far
# -------------------------------
# LoadJob<project=neo4jgraphconnectdemo2022, location=US, id=d1a5af4d-98c1-4e80-9286-a0338bcf5d37>
# Finished year 1989. Predicted 24724141 papers so far
# -------------------------------
# LoadJob<project=neo4jgraphconnectdemo2022, location=US, id=f1f5e2e2-dade-40bc-92fc-cce5db34e6a1>
# Finished year 1990. Predicted 26012414 papers so far
# -------------------------------
# LoadJob<project=neo4jgraphconnectdemo2022, location=US, id=04840d58-041e-456f-925a-27b875c786e2>
# Finished year 1991. Predicted 27284531 papers so far
# -------------------------------
# LoadJob<project=neo4jgraphconnectdemo2022, location=US, id=eb265015-975a-4105-b546-a68049e4962a>
# Finished year 1992. Predicted 28598150 papers so far
# -------------------------------
# LoadJob<project=neo4jgraphconnectdemo2022, location=US, id=18d00a66-5d28-4a0b-9955-6ca3c076b15e>
# Finished year 1993. Predicted 29976618 papers so far
# -------------------------------
# LoadJob<project=neo4jgraphconnectdemo2022, location=US, id=f476ffd1-6c4d-4b0e-9f72-365194311c76>
# Finished year 1994. Predicted 31403554 papers so far
# -------------------------------
# LoadJob<project=neo4jgraphconnectdemo2022, location=US, id=e9704e08-2f1b-4457-9baa-85df9292bc4a>
# Finished year 1995. Predicted 32897297 papers so far
# -------------------------------
# LoadJob<project=neo4jgraphconnectdemo2022, location=US, id=7a840efa-34a4-43cc-970e-29d67957d5f3>
# Finished year 1996. Predicted 34463525 papers so far
# -------------------------------
# LoadJob<project=neo4jgraphconnectdemo2022, location=US, id=cd2e74bf-1044-419f-a6cb-6fe69bb50175>
# Finished year 1997. Predicted 36091090 papers so far
# -------------------------------
# LoadJob<project=neo4jgraphconnectdemo2022, location=US, id=ef27bded-43fd-48ce-a1fd-f498a03de68a>
# Finished year 1998. Predicted 37794832 papers so far
# -------------------------------
# LoadJob<project=neo4jgraphconnectdemo2022, location=US, id=fd1d158c-35d5-4283-9d9a-524b22de1322>
# Finished year 2002. Predicted 45803015 papers so far
# -------------------------------
# LoadJob<project=neo4jgraphconnectdemo2022, location=US, id=5bb2949e-8fa0-4846-9c79-8bf96568d477>
# Finished year 2003. Predicted 48202500 papers so far
# -------------------------------
# LoadJob<project=neo4jgraphconnectdemo2022, location=US, id=933c65b4-f9d3-482f-a1b4-c2ff6ce20b94>
# Finished year 2004. Predicted 50851651 papers so far
# -------------------------------
# LoadJob<project=neo4jgraphconnectdemo2022, location=US, id=20891f52-19f8-41b0-81a5-3a83e61eb31c>
# Finished year 2005. Predicted 53739818 papers so far
# -------------------------------
# LoadJob<project=neo4jgraphconnectdemo2022, location=US, id=dba263f6-3754-4ed4-b3a0-11eea56319a3>
# Finished year 2006. Predicted 56953311 papers so far
# -------------------------------
# LoadJob<project=neo4jgraphconnectdemo2022, location=US, id=46540258-6ac1-483d-868e-a4672a9c689d>
# Finished year 2007. Predicted 60384246 papers so far
# -------------------------------
# LoadJob<project=neo4jgraphconnectdemo2022, location=US, id=418087b3-b9ee-49ab-9487-75576363d043>
# Finished year 2008. Predicted 64147900 papers so far
# -------------------------------
# LoadJob<project=neo4jgraphconnectdemo2022, location=US, id=af6796cb-1c5b-4fff-8d5a-782fb4a24f46>
# Finished year 2009. Predicted 68258571 papers so far
# -------------------------------
# LoadJob<project=neo4jgraphconnectdemo2022, location=US, id=05e7dd7c-1cf7-421d-8345-f7f7b279db72>
# Finished year 2010. Predicted 72633055 papers so far
# -------------------------------
# LoadJob<project=neo4jgraphconnectdemo2022, location=US, id=35a90d33-62d0-486e-91ff-6f0e03872aa6>
# Finished year 2011. Predicted 77199834 papers so far
# -------------------------------
# LoadJob<project=neo4jgraphconnectdemo2022, location=US, id=848d65db-56f9-48a3-a662-4259b36edbe1>
# Finished year 2012. Predicted 81949879 papers so far
# -------------------------------
# LoadJob<project=neo4jgraphconnectdemo2022, location=US, id=de38e480-6a70-41c6-a18a-1655a1e05b91>
# Finished year 2013. Predicted 86942757 papers so far
# -------------------------------
# LoadJob<project=neo4jgraphconnectdemo2022, location=US, id=86b71576-712f-4ff4-98b0-48be838771e9>
# Finished year 2014. Predicted 91991186 papers so far
# -------------------------------
# LoadJob<project=neo4jgraphconnectdemo2022, location=US, id=9b859f88-ba01-4123-a3af-428982c2bb7d>
# Finished year 2015. Predicted 97110600 papers so far
# -------------------------------
# LoadJob<project=neo4jgraphconnectdemo2022, location=US, id=18a6fcd5-7a02-4fff-89a3-94db3622cf55>
# Finished year 2016. Predicted 102278644 papers so far
# -------------------------------
# LoadJob<project=neo4jgraphconnectdemo2022, location=US, id=4eb04d81-fb17-41fc-a98e-6510c075dad0>
# Finished year 2019. Predicted 117368891 papers so far
# -------------------------------
# LoadJob<project=neo4jgraphconnectdemo2022, location=US, id=d4266119-f650-4936-aec8-5ef9d9b47433>
# Finished year 2020. Predicted 121695785 papers so far
# -------------------------------
# LoadJob<project=neo4jgraphconnectdemo2022, location=US, id=5fc28412-b676-417c-8986-6faa39909689>
# Finished year 2021. Predicted 121751663 papers so far
# -------------------------------
